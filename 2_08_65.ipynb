# %% [markdown]
# <a href="https://colab.research.google.com/github/Phruetti/sc607703-1/blob/main/2_08_65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df2 = pd.read_csv(io.BytesIO(uploaded['iris.csv']))
type(df2)
# Out:
#      <input type="file" id="files-5ebb002b-7b1e-466c-890a-6f762801941a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebb002b-7b1e-466c-890a-6f762801941a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv
# pandas.core.frame.DataFrame

# %%
# %R -i df2

# %%
# %%R
# df2
# Out:
#     sepal.length sepal.width petal.length petal.width    variety
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# 5            5.4         3.9          1.7         0.4     Setosa
# 6            4.6         3.4          1.4         0.3     Setosa
# 7            5.0         3.4          1.5         0.2     Setosa
# 8            4.4         2.9          1.4         0.2     Setosa
# 9            4.9         3.1          1.5         0.1     Setosa
# 10           5.4         3.7          1.5         0.2     Setosa
# 11           4.8         3.4          1.6         0.2     Setosa
# 12           4.8         3.0          1.4         0.1     Setosa
# ...

# %%
# %%R
# df3 =df2[1:10,c(1,3)] #เลือกแค่ตัวแปล 1dy[3]
# df3
# Out:
#   sepal.length petal.length
# 0          5.1          1.4
# 1          4.9          1.4
# 2          4.7          1.3
# 3          4.6          1.5
# 4          5.0          1.4
# 5          5.4          1.7
# 6          4.6          1.4
# 7          5.0          1.5
# 8          4.4          1.4
# 9          4.9          1.5

# %%
# %%R
# install.packages("car")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘minqa’, ‘Rcpp’, ‘RcppEigen’, ‘pbkrtest’, ‘lme4’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/minqa_1.2.4.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 53548 bytes (52 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library("car")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: carData

# %%
# %%R
# scatterplot(sepal.length ~ petal.length ,data=df2)

# %%
# %%R
# scatterplot(sepal.length ~ petal.length| variety ,data=df2)

# %%
# %%R
# #Setosa = df2[df2$variety =='Setosa',] พี่ไอ
# scatterplot(sepal.length ~ petal.length ,data=Setosa)

# %% [markdown]
# multivariate normal distribution simulation

# %%
# %%R
# install.packages("MASS")
# install.packages("ggplot2")
# install.packages("MVN")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/MASS_7.3-58.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 503817 bytes (492 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library("MASS")
# library("ggplot2")
# library("MVN")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in library("MVN") : there is no package called ‘MVN’
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In addition:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Warning messages:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 1:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In install.packages("MVN") :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  installation of package ‘gsl’ had non-zero exit status
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: 2:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: In install.packages("MVN") :
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  installation of package ‘energy’ had non-zero exit status
#
# ...
